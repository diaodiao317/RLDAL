# %%
import numpy as np

# %%
splits = np.load('tn3k_al_splits.npy',allow_pickle=True).item()

# %%
print(f"pt_set size: {len(splits['p_t'])}")
# print(f"dv_set size: {len(splits['d_v'])}")
print(f"ds_set size: {len(splits['d_s'])}")
print(f"tq_set size: {len(splits['t_q'])}")
print(f"dt_set size: {len(splits['d_t'])}")
# Out:
# pt_set size: 71
# ds_set size: 10
# tq_set size: 71
# dt_set size: 2727

# %%
len(splits['d_t'])
# Out:
# 2727

# %%
test = np.load('kvasir_al_splits.npy',allow_pickle=True).item()

# %%
test
# Out:
# {'p_t': ['cju2y0z6g87p10878fpk5d3rq.png',
#   'cju77vvcwzcm50850lzoykuva.png',
#   'cju5jx7jzf7c90871c2i9aiov.png',
#   'cju7amjna1ly40871ugiokehb.png',
#   'cju7ebe962hr409872ovibahw.png',
#   'cju88nroho44508500129f1nh.png',
#   'cju45n0oxn5vu08500yfrt9jn.png',
#   'cju2t2ivz43i10878zeg8r1br.png',
#   'cju77g99iyxc00817zqi2ppor.png',
#   'cju5bf6hxa6m50817rbwettgu.png',
#   'cju7dff9529h208503w60lbil.png',
#   'cju7g7ba42z310987bqzbi2bq.png',
#   'cju8cgi2kspp308011nxdtjp6.png',
#   'cju85omszllp30850b6rm9mi3.png',
#   'cju1fmsyf6gxb0801cimx2gle.png',
#   'cju8a3nhbpwnb0850d37fo2na.png',
#   'cju2lyynuymli0855g7fxgbhe.png',
#   'cju41lojblbs307555jdci937.png',
#   'cju5b9oyda4yr0850g9viziyv.png',
#   'cju83vvmik9wa08710yeh7cuk.png',
#   'cju3u39fog1bo0871lxjrabks.png',
#   'cju3u815rg4ek0850vvhtcvcm.png',
#   'cju8418jhkf7d0818ga2v0xq0.png',
#   'cju3xl264ingx0850rcf0rshj.png',
#   'cju8914beokbf0850isxpocrk.png',
#   'cju7dmlgf2ebw0871ieqas5fh.png',
# ...
